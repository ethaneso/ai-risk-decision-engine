# %%
import sys
import os

# Add parent directory (project root) to Python path
sys.path.append(os.path.abspath('..'))

# %%
import os

# Print current working directory
print(os.getcwd())
# Out:
# /Volumes/BLACKRED/Projects/ai-risk-decison-engine/notebooks

# %%
# Now your import will work:
from src.app.ingestion.parser import parse_pdf

pages = parse_pdf("../documents/Megtech_cyberseucirty_incident_handling_policy.pdf")
print(len(pages))
print(pages[1])
# Out:
# 4
# ...

# %%
from src.app.ingestion.cleaner import clean_text


def test_clean_text():
    text = "Hello    world\n\nthis is   a test."

    result = clean_text(text)

    assert result == "Hello world this is a test."
